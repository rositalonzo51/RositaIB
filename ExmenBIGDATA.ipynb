# %%
import pandas as pd
import numpy as np

# %%
# !unzip avocado-prices.zip
# Out:
# Archive:  avocado-prices.zip
# replace avocado.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# !ls
# Out:
# 'Exmen 2.ipynb'   avocado-prices.zip   avocado.csv

# %%
df= pd.read_csv('avocado.csv', encoding='latin1')

# %%
df
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
import matplotlib.pyplot as plt

# %%
Precio_agua = AveragePrice.cumsum() #Primer punto
Precio_agua
# Out:
#        AveragePrice
# 0              1.33
# 1              2.68
# 2              3.61
# 3              4.69
# 4              5.97
# ...             ...
# 18244      25650.57
# 18245      25652.28
# 18246      25654.15
# 18247      25656.08
# 18248      25657.70
#
# [18249 rows x 1 columns]

# %%
AveragePrice=df.loc[:, ['AveragePrice']]
AveragePrice.T
# Out:
#               0      1      2      3      4      5      6      7      8      \
# AveragePrice   1.33   1.35   0.93   1.08   1.28   1.26   0.99   0.98   1.02
#
#               9      ...  18239  18240  18241  18242  18243  18244  18245  \
# AveragePrice   1.07  ...   1.56   1.54   1.57   1.56   1.57   1.63   1.71
#
#               18246  18247  18248
# AveragePrice   1.87   1.93   1.62
#
# [1 rows x 18249 columns]

# %%
df['AveragePrice'].max()
# Out:
# 3.25

# %%
#1 .- El precio promedio mas alto del aguacates vendidos
Respuesta1= "El promedio mas alto es  %" + str(AveragePrice['AveragePrice'].max())
Respuesta1
# Out:
# 'El promedio mas alto es  %3.25'

# %%
df['AveragePrice'].describe()
# Out:
# count    18249.000000
# mean         1.405978
# std          0.402677
# min          0.440000
# 25%          1.100000
# 50%          1.370000
# 75%          1.660000
# max          3.250000
# Name: AveragePrice, dtype: float64

# %%
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
ploteo=df[["Small Bags", "Large Bags","XLarge Bags"]]
ploteo
# Out:
#        Small Bags  Large Bags  XLarge Bags
# 0         8603.62       93.25          0.0
# 1         9408.07       97.49          0.0
# 2         8042.21      103.14          0.0
# 3         5677.40      133.76          0.0
# 4         5986.26      197.69          0.0
# ...           ...         ...          ...
# 18244    13066.82      431.85          0.0
# 18245     8940.04      324.80          0.0
# 18246     9351.80       42.31          0.0
# 18247    10919.54       50.00          0.0
# 18248    11988.14       26.01          0.0
#
# [18249 rows x 3 columns]

# %%
from matplotlib import pyplot as pl
# %matplotlib inline
import seaborn as sns

# %%
sns.pairplot(ploteo, kind="reg")#2 .- Grafique las bolsas pequeñas grandes y extragrandes vendidas La comporacion de
#la venta de aguantes organicos en bolsas pequeñas
plt.show()

# %%
df.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %%
tipos_agua = df.groupby(['Unnamed: 0','type'])
tipos_2 = tipos_agua['AveragePrice'].sum()
tipos_2.unstack()
# Out:
# type        conventional  organic
# Unnamed: 0
# 0                 231.25   334.53
# 1                 240.07   340.55
# 2                 234.79   337.58
# 3                 232.55   346.04
# 4                 249.81   353.19
# 5                 261.32   354.97
# 6                 254.12   364.85
# 7                 251.11   364.07
# 8                 265.04   378.53
# 9                 266.74   370.60
# 10                277.50   366.63
# 11                278.42   369.21
# 12                219.72   302.51
# 13                218.80   306.15
# 14                211.95   298.64
# 15                206.43   295.72
# 16                206.02   296.12
# 17                210.85   293.27
# 18                205.41   299.15
# 19                202.30   295.30
# 20                199.81   285.03
# 21                204.85   284.53
# 22                202.05   280.99
# 23                197.29   275.86
# 24                194.91   274.50
# 25                185.39   273.48
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
#3 .- ¿Cuál es el promedio de bolsas vendidas para los tamaños de bolsas?
df['Total Bags'].describe()
# Out:
# count    1.824900e+04
# mean     2.396392e+05
# std      9.862424e+05
# min      0.000000e+00
# 25%      5.088640e+03
# 50%      3.974383e+04
# 75%      1.107834e+05
# max      1.937313e+07
# Name: Total Bags, dtype: float64

# %%
TotalBags=df.loc[:, ['Total Bags']]
TotalBags.T
# Out:
#               0        1        2        3        4        5        6      \
# Total Bags  8696.87  9505.56  8145.35  5811.16  6183.95  6683.91  8318.86
#
#               7         8        9      ...     18239     18240     18241  \
# Total Bags  6829.22  11388.36  8625.92  ...  16762.57  13655.49  13964.33
#
#                18242     18243     18244    18245    18246     18247     18248
# Total Bags  13776.71  12693.57  13498.67  9264.84  9394.11  10969.54  12014.15
#
# [1 rows x 18249 columns]

# %%
df['Total Bags'].max()
# Out:
# 19373134.37

# %%
Respuesta2 = "El promedio de la bolsas mas vendidadas son:   %" + str(TotalBags['Total Bags'].max())
Respuesta2
# Out:
# 'El promedio de la bolsas mas vendidadas son:   %19373134.37'

# %%
# 4. ¿cual seria los tipos de region?
pd.unique(df['region'])
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
ploteo1=df[["AveragePrice", "type","region"]]
ploteo1
# Out:
#        AveragePrice          type            region
# 0              1.33  conventional            Albany
# 1              1.35  conventional            Albany
# 2              0.93  conventional            Albany
# 3              1.08  conventional            Albany
# 4              1.28  conventional            Albany
# ...             ...           ...               ...
# 18244          1.63       organic  WestTexNewMexico
# 18245          1.71       organic  WestTexNewMexico
# 18246          1.87       organic  WestTexNewMexico
# 18247          1.93       organic  WestTexNewMexico
# 18248          1.62       organic  WestTexNewMexico
#
# [18249 rows x 3 columns]

# %%
sns.pairplot(ploteo1, kind="reg")
plt.show()
